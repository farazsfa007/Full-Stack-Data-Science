# %%
# pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("services.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df[['service_areas','email','funding_sources']]
# Out:
#                             service_areas                  email  \
# 0                                   Colma                    NaN
# 1                        San Mateo County                    NaN
# 2                        San Mateo County                    NaN
# 3                        San Mateo County                    NaN
# 4                        San Mateo County                    NaN
# 5                        San Mateo County                    NaN
# 6     Belmont, Burlingame, East Palo Alto                    NaN
# 7                 Belmont, East Palo Alto                    NaN
# 8                        San Mateo County                    NaN
# 9                        San Mateo County                    NaN
# 10                       San Mateo County                    NaN
# 11                              Daly City                    NaN
# 12                       San Mateo County                    NaN
# ...

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
pd.read_csv("https://media.githubusercontent.com/media/datablist/sample-csv-files/main/files/customers/customers-100.csv")
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
url_data = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2023_totals.html")

# %%
url_data
# Out:
# [      Rk            Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
#  0      1  Precious Achiuwa   C  23  TOR  55  12  1140  196   404  ...  .702
#  1      2      Steven Adams   C  29  MEM  42  42  1133  157   263  ...  .364
#  2      3       Bam Adebayo   C  25  MIA  75  75  2598  602  1114  ...  .806
#  3      4      Ochai Agbaji  SG  22  UTA  59  22  1209  165   386  ...  .812
#  4      5      Santi Aldama  PF  22  MEM  77  20  1682  247   525  ...  .750
#  ..   ...               ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
#  700  535    Thaddeus Young  PF  34  TOR  54   9   795  108   198  ...  .692
#  701  536        Trae Young  PG  24  ATL  73  73  2541  597  1390  ...  .886
#  702  537    Omer Yurtseven   C  24  MIA   9   0    83   16    27  ...  .833
#  703  538       Cody Zeller   C  30  MIA  15   2   217   37    59  ...  .686
#  704  539       Ivica Zubac   C  25  LAC  76  76  2170  326   514  ...  .697
#
# ...

# %%
type(url_data)
# Out:
# list

# %%
len(url_data)
# Out:
# 1

# %%
df2 = url_data[0]

# %%
df2.head()
# Out:
#   Rk            Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 0  1  Precious Achiuwa   C  23  TOR  55  12  1140  196   404  ...  .702  100
# 1  2      Steven Adams   C  29  MEM  42  42  1133  157   263  ...  .364  214
# 2  3       Bam Adebayo   C  25  MIA  75  75  2598  602  1114  ...  .806  184
# 3  4      Ochai Agbaji  SG  22  UTA  59  22  1209  165   386  ...  .812   43
# 4  5      Santi Aldama  PF  22  MEM  77  20  1682  247   525  ...  .750   85
#
#    DRB  TRB  AST STL BLK  TOV   PF   PTS
# 0  228  328   50  31  30   59  102   508
# 1  271  485   97  36  46   79   98   361
# 2  504  688  240  88  61  187  208  1529
# 3   78  121   67  16  15   41   99   467
# 4  286  371   97  45  48   60  143   696
#
# [5 rows x 30 columns]

# %%
df2.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df2.to_csv("NBA 2023 Players",index=False,columns=None) #it will save file to csv format

# %%
df2[['Rk','Player','Pos']].to_csv("NBA 2023 Players pos player")
