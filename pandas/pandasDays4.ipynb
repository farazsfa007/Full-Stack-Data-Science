# %%
import pandas as pd

# %%
df = pd.read_csv("people.csv")

# %%
df.columns
# Out:
# Index(['Index', 'User Id', 'First Name', 'Last Name', 'Sex', 'Email', 'Phone',
#        'Date of birth', 'Job Title'],
#       dtype='object')

# %%
df.drop
# Out:
# <bound method DataFrame.drop of     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1        bethany14@example.com       214.112.6044x4913    1910-03-24
# ...

# %%
df.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1       bethany14@example.com       214.112.6044x4913    1910-03-24
# 2       bthompson@example.com            277.609.7938    1992-07-02
# 3   kaitlinkaiser@example.com            584.094.6111    2017-08-03
# 4  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title
# 0     Games developer
# 1      Phytotherapist
# 2           Homeopath
# 3   Market researcher
# 4  Veterinary surgeon

# %%
df.set_index("Job Title",inplace=True)

# %%
df
# Out:
#                        Index          User Id First Name  Last Name     Sex  \
# Job Title
# Games developer            1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# Phytotherapist             2  f90cD3E76f1A9b9    Phillip    Summers  Female
# Homeopath                  3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# Market researcher          4  A31Bee3c201ef58    Yesenia   Martinez    Male
# Veterinary surgeon         5  1bA7A3dc874da3c       Lori       Todd    Male
# ...                      ...              ...        ...        ...     ...
# Software engineer         96  5eFda7caAeB260E     Dennis     Barnes  Female
# Barrister                 97  CCbFce93d3720bE      Steve  Patterson  Female
# Police officer            98  2fEc528aFAF0b69     Wesley       Bray    Male
# Broadcast journalist      99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# IT sales professional    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
# ...

# %%
# df.reset_index()

# %%
df.drop("User Id",axis=1,inplace=True)

# %%
df
# Out:
#                        Index First Name  Last Name     Sex  \
# Job Title
# Games developer            1     Shelby    Terrell    Male
# Phytotherapist             2    Phillip    Summers  Female
# Homeopath                  3   Kristine     Travis    Male
# Market researcher          4    Yesenia   Martinez    Male
# Veterinary surgeon         5       Lori       Todd    Male
# ...                      ...        ...        ...     ...
# Software engineer         96     Dennis     Barnes  Female
# Barrister                 97      Steve  Patterson  Female
# Police officer            98     Wesley       Bray    Male
# Broadcast journalist      99     Summer   Oconnell  Female
# IT sales professional    100     Mariah    Bernard    Male
#
#                                             Email                   Phone  \
# Job Title
# Games developer              elijah57@example.net  001-084-906-7849x73518
# Phytotherapist              bethany14@example.com       214.112.6044x4913
# ...

# %%
df.dtypes
# Out:
# Index             int64
# First Name       object
# Last Name        object
# Sex              object
# Email            object
# Phone            object
# Date of birth    object
# dtype: object

# %%
g = df.groupby('Sex')

# %%
g.mean
# Out:
# <bound method GroupBy.mean of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x00000140794DA930>>

# %%
df[0:10]
# Out:
#                           Index First Name Last Name     Sex  \
# Job Title
# Games developer               1     Shelby   Terrell    Male
# Phytotherapist                2    Phillip   Summers  Female
# Homeopath                     3   Kristine    Travis    Male
# Market researcher             4    Yesenia  Martinez    Male
# Veterinary surgeon            5       Lori      Todd    Male
# Waste management officer      6       Erin       Day    Male
# Intelligence analyst          7  Katherine      Buck  Female
# Hydrogeologist                8    Ricardo    Hinton    Male
# Lawyer                        9       Dave   Farrell    Male
# Engineer, site               10     Isaiah     Downs    Male
#
#                                                 Email                   Phone  \
# Job Title
# Games developer                  elijah57@example.net  001-084-906-7849x73518
# Phytotherapist                  bethany14@example.com       214.112.6044x4913
# ...

# %%
d = {'key1':[1,2,3,4,5],
     'key2':[6,7,8,9,10],
     'key3':[10,3,5,3,2]}

# %%
type(d)
# Out:
# dict

# %%
d1 = pd.DataFrame(d)

# %%
type(d1)
# Out:
# pandas.core.frame.DataFrame

# %%
d1
# Out:
#    key1  key2  key3
# 0     1     6    10
# 1     2     7     3
# 2     3     8     5
# 3     4     9     3
# 4     5    10     2

# %%
df
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1        bethany14@example.com       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...
