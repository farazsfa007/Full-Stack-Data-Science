# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq
import logging

# %%
flipcart_url = "https://www.flipkart.com/search?q="+"pocom2"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=pocom2'

# %%
urlclient = uReq(flipcart_url)

# %%
urlclient

# %%
flipcart_page = urlclient.read()

# %%
flicart_html = bs(flipcart_page,"html.parser")

# %%
"https://www.flipkart.com/"+"apple-iphone-13-pro-max-alpine-green-1-tb/p/itm85829ae4949a7?pid=MOBGC9VGF6TPMQKZ&lid=LSTMOBGC9VGF6TPMQKZPDWLNQ&marketplace=FLIPKART&q=iphone13pro&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=231f13ab-94cd-4327-9213-64c4b914d105.MOBGC9VGF6TPMQKZ.SEARCH&ppt=sp&ppn=sp&ssid=773jioplkg0000001706367334778&qH=43c39800153648da"
# Out:
# 'https://www.flipkart.com/apple-iphone-13-pro-max-alpine-green-1-tb/p/itm85829ae4949a7?pid=MOBGC9VGF6TPMQKZ&lid=LSTMOBGC9VGF6TPMQKZPDWLNQ&marketplace=FLIPKART&q=iphone13pro&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=231f13ab-94cd-4327-9213-64c4b914d105.MOBGC9VGF6TPMQKZ.SEARCH&ppt=sp&ppn=sp&ssid=773jioplkg0000001706367334778&qH=43c39800153648da'

# %%
bigbox = flicart_html.findAll("div",{"class":"_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 30

# %%
del bigbox[0:3]

# %%
productlink = "https://www.flipkart.com"+bigbox[2].div.div.div.a['href']

# %%
product_req = requests.get(productlink)

# %%
productlink
# Out:
# 'https://www.flipkart.com/poco-m2-pro-green-greener-64-gb/p/itm795e36b373b6f?pid=MOBFT7MK3Q89BGWR&lid=LSTMOBFT7MK3Q89BGWRDWVFC8&marketplace=FLIPKART&q=pocom2&store=tyy%2F4io&srno=s_1_4&otracker=search&fm=organic&iid=4743de32-3da5-45e1-8274-c491e0571f26.MOBFT7MK3Q89BGWR.SEARCH&ppt=None&ppn=None&ssid=1064wl1rao0000001706697714143&qH=8639b5ffb256e82c'

# %%
product_html = bs(product_req.text,"html.parser")

# %%
comment_box = product_html.find_all("div",{"class":"_16PBlm"})

# %%
comment_box[0].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Ajay Yadav'

# %%
for j in comment_box:
    try:
        value2 = j.div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text
        print(value2)
    except AttributeError as e:
        continue
# Out:
# Ajay Yadav
# PRASHANT
# kumar das
# Flipkart Customer
# Pritisa Mondal
# Thirumal Thangaraj
# Dheeraj Kumar Jha Jha
# Rajeev Kumar
# Mohammed Nayeem Ansari
# Priya Nandi

# %%
comment_box[0].div.div.div.div.text
# Out:
# '5'

# %%
for i in comment_box:
    try:
        value0 = i.div.div.div.div.text
        print(value0)
    except AttributeError as e:
        continue
# Out:
# 5
# 5
# 4
# 4
# 4
# 5
# 5
# 5
# 5
# 5

# %%
comment_box[0].div.div.div.p.text
# Out:
# 'Classy product'

# %%
for i in comment_box:
    try:
        value1 = i.div.div.div.p.text
        print(value1)
    except AttributeError as e:
        continue
# Out:
# Classy product
# Perfect product!
# Good quality product
# Worth the money
# Wonderful
# Best in the market!
# Just wow!
# Perfect product!
# Great product
# Brilliant

# %%
comment_box[0].div.div.find_all('div',{"class":''})[0].div.text
# Out:
# 'Excellent device in this price range. Go for it.720G is a very good processor.'

# %%
for i in comment_box:
    try:
        value = i.div.div.find_all('div', {"class": ''})[0].div.text
        print(value)
    except AttributeError as e:
        continue
# Out:
# Excellent device in this price range. Go for it.720G is a very good processor.
# Every thing is perfect according to the price but camera is average
# Just amazing 💘
# Must recommend phone. Value for money
# Veryyy nicee💥💥❤️❤️🤩🤩🔥🔥 good camera quality 😪♥️ awesome display 😍💘nice battery life 😚💥 I'm very happy to buy this product 😃☺️
# Perfect fit
# Beautiful mobile in this price
# The phone offers good performance, average display, long battery life, a spectacular design, and a camera that takes good daylight pictures. The poco m2 pro is a value for money device and I believe it is can give tough competition to its closest
# This is typical of Xiaomi phones. Only exception is  phone has less adsPacked with miui 12 features. Camera is pretty good. Nice display and I loved its back design. I dnt play too many games but the performance is very good. Didn't feel any lag.... If u want budget phone and a redmi fan go for it
# ...

# %%
for i in bigbox:
    try:
        value = "https://www.flipkart.com"+i.div.div.div.a['href']
        print(value)
    except AttributeError as e:
        continue
# Out:
# https://www.flipkart.com/poco-m2-pro-green-greener-128-gb/p/itm0790688fdea0e?pid=MOBFT7MKBN2PUCWA&lid=LSTMOBFT7MKBN2PUCWAG1ID9L&marketplace=FLIPKART&q=pocom2&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=4743de32-3da5-45e1-8274-c491e0571f26.MOBFT7MKBN2PUCWA.SEARCH&ppt=None&ppn=None&ssid=1064wl1rao0000001706697714143&qH=8639b5ffb256e82c
# https://www.flipkart.com/poco-m2-pro-green-greener-64-gb/p/itm5de3b6eb57ab4?pid=MOBFT7MKFHTAPDYD&lid=LSTMOBFT7MKFHTAPDYD4U5LJM&marketplace=FLIPKART&q=pocom2&store=tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=4743de32-3da5-45e1-8274-c491e0571f26.MOBFT7MKFHTAPDYD.SEARCH&ppt=None&ppn=None&ssid=1064wl1rao0000001706697714143&qH=8639b5ffb256e82c
# ...

# %%
product_html
# Out:
# <!DOCTYPE html>
# ...
